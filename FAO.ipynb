# %%
import pandas as pd 
import seaborn as sns 
import numpy as np

# %%
food = pd.read_csv('food.csv')
food.head(20)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
food.groupby('Item')[['Y2014','Y2017']].sum()
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
food['Y2015'].mean(),food['Y2015'].std()
# Out:
# (135.23596649549236, 1603.4039839423301)

# %%
food['Y2016'].isnull().sum()/food['Y2016'].count() * 100
# Out:
# 2.583827093994075

# %%
food['Element Code'].corr
# Out:
# <bound method Series.corr of 0         511
# 1        5301
# 2         664
# 3         674
# 4         684
#          ...
# 60938    5142
# 60939     645
# 60940     664
# 60941     674
# 60942     684
# Name: Element Code, Length: 60943, dtype: int64>

# %%
food.groupby('Element').get_group('Production')['Y2014'].sum()
# Out:
# 1931287.75

# %%
food.groupby('Element')[['Y2018','Element']].sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %%
food.groupby('Element').first()
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2905
# Fat supply quantity (g/capita/day)              4  Algeria       2901
# Feed                                            4  Algeria       2905
# Food                                            4  Algeria       2905
# Food supply (kcal/capita/day)                   4  Algeria       2901
# Food supply quantity (kg/capita/yr)             4  Algeria       2905
# Import Quantity                                 4  Algeria       2905
# Losses                                          4  Algeria       2905
# Other uses (non-food)                           4  Algeria       2905
# Processing                                      4  Algeria       2905
# Production                                      4  Algeria       2905
# ...

# %%
len(food['Area'].value_counts())
# Out:
# 49

# %%
food.groupby('Element').max()
# Out:
#                                         Area Code                   Area  \
# Element
# Domestic supply quantity                      276               Zimbabwe
# Export Quantity                               276               Zimbabwe
# Fat supply quantity (g/capita/day)            276               Zimbabwe
# Feed                                          276               Zimbabwe
# Food                                          276               Zimbabwe
# Food supply (kcal/capita/day)                 276               Zimbabwe
# Food supply quantity (kg/capita/yr)           276               Zimbabwe
# Import Quantity                               276               Zimbabwe
# Losses                                        276               Zimbabwe
# Other uses (non-food)                         276               Zimbabwe
# Processing                                    276               Zimbabwe
# Production                                    276               Zimbabwe
# ...

# %%
quantity = food.groupby(['Element']).get_group('Import Quantity')
quantity[quantity['Area']=='Algeria'].sum()
# Out:
# Area Code                                                     448
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                  301030
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                               628432
# Element         Import QuantityImport QuantityImport QuantityI...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                    34940.12
# Y2015                                                    37841.91
# Y2016                                                    36736.08
# Y2017                                                    36059.29
# Y2018                                                    36238.29
# dtype: object
